# %%
from pathlib import Path

print("modules imported successfully")
# Out:
# modules imported successfully

# %%
text_path = Path("one_piece.txt")
if not text_path.exists():
    text_path = Path("human-conversation") / "one_piece.txt"

text = text_path.read_text(encoding="utf-8")
words = text.split()

# %%
def get_stats(ids):
    counts = {}
    for pair in zip(ids, ids[1:]):
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

# %%
merges = {}
vocab = {idx: bytes([idx]) for idx in range(256)}

# %%
def decode(ids):
  # given ids (list of integers), return Python string
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors="replace")
  return text

def encode(text):
  # given a string, return list of integers (the tokens)
  tokens = list(text.encode("utf-8"))
  while len(tokens) >= 2:
    stats = get_stats(tokens)
    pair = min(stats, key=lambda p: merges.get(p, float("inf")))
    if pair not in merges:
      break # nothing else can be merged
    idx = merges[pair]
    tokens = merge(tokens, pair, idx)
  return tokens

# %%
#Running the whole Project ones:

# %%
encode
# Out:
# <function __main__.encode(text)>

# %%
encode("hello")
# Out:
# [104, 101, 108, 108, 111]

# %%
tokens = text.encode("utf-8") # raw bytes
tokens = list(map(int, tokens)) # convert to a list of integers in range 0..255 for convenience
print("length:", len(text))
print("first 100 tokens:", tokens[:100])
print("length:", len(tokens))
# Out:
# length: 251470
# first 100 tokens: [79, 110, 101, 32, 80, 105, 101, 99, 101, 32, 226, 128, 147, 32, 82, 111, 109, 97, 110, 99, 101, 32, 68, 97, 119, 110, 32, 65, 114, 99, 10, 87, 101, 108, 99, 111, 109, 101, 32, 116, 111, 32, 116, 104, 101, 32, 100, 97, 119, 110, 32, 111, 102, 32, 104, 105, 115, 116, 111, 114, 121, 46, 32, 84, 104, 101, 32, 115, 116, 111, 114, 121, 32, 98, 101, 103, 105, 110, 115, 32, 119, 105, 116, 104, 32, 116, 104, 101, 32, 101, 120, 101, 99, 117, 116, 105, 111, 110, 32, 111]
# length: 251622

# %%
stats = get_stats(tokens)
print("unique byte pairs:", len(stats))
print("most common pairs:", sorted(stats.items(), key=lambda item: item[1], reverse=True)[:10])
# Out:
# unique byte pairs: 1360
# most common pairs: [((32, 116), 7504), ((101, 32), 7256), ((104, 101), 5742), ((116, 104), 5737), ((115, 32), 5696), ((32, 97), 4790), ((105, 110), 3913), ((100, 32), 3647), ((116, 32), 3389), ((97, 110), 3356)]

# %%
vocab_size = 512 
num_merges = vocab_size - 256
ids = list(tokens) #Make a duplicate to avoid destroying our original list

# %%
merges = {}
new_id = []
for i in range(num_merges):
  if len(ids) < 2:
    break
  stats = get_stats(ids)
  pair = max(stats, key=stats.get)
  idx = 256 + i
  new_id.append(idx)
  print(f"merging {pair} into a new token {idx}")
  ids = merge(ids, pair, idx)
  merges[pair] = idx

vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]
# Out:
# merging (32, 116) into a new token 256
# merging (101, 32) into a new token 257
# merging (256, 104) into a new token 258
# merging (115, 32) into a new token 259
# merging (105, 110) into a new token 260
# merging (32, 97) into a new token 261
# merging (101, 114) into a new token 262
# merging (100, 32) into a new token 263
# merging (258, 257) into a new token 264
# merging (116, 32) into a new token 265
# merging (111, 32) into a new token 266
# merging (44, 32) into a new token 267
# merging (97, 110) into a new token 268
# merging (111, 110) into a new token 269
# merging (114, 101) into a new token 270
# merging (121, 32) into a new token 271
# merging (260, 103) into a new token 272
# merging (97, 116) into a new token 273
# merging (111, 114) into a new token 274
# merging (46, 32) into a new token 275
# merging (104, 105) into a new token 276
# merging (101, 110) into a new token 277
# merging (261, 110) into a new token 278
# merging (256, 266) into a new token 279
# merging (97, 114) into a new token 280
# merging (108, 108) into a new token 281
# merging (111, 117) into a new token 282
# merging (105, 116) into a new token 283
# merging (111, 102) into a new token 284
# merging (115, 116) into a new token 285
# merging (278, 263) into a new token 286
# merging (272, 32) into a new token 287
# merging (258, 101) into a new token 288
# merging (101, 115) into a new token 289
# merging (262, 32) into a new token 290
# merging (111, 109) into a new token 291
# merging (111, 119) into a new token 292
# merging (115, 101) into a new token 293
# merging (104, 257) into a new token 294
# merging (108, 101) into a new token 295
# merging (97, 99) into a new token 296
# merging (104, 97) into a new token 297
# merging (98, 101) into a new token 298
# merging (105, 114) into a new token 299
# merging (39, 259) into a new token 300
# merging (104, 32) into a new token 301
# merging (101, 259) into a new token 302
# merging (261, 32) into a new token 303
# merging (101, 263) into a new token 304
# merging (97, 108) into a new token 305
# merging (102, 274) into a new token 306
# merging (97, 109) into a new token 307
# merging (105, 115) into a new token 308
# merging (102, 102) into a new token 309
# merging (97, 265) into a new token 310
# merging (76, 117) into a new token 311
# merging (101, 100) into a new token 312
# merging (276, 259) into a new token 313
# merging (105, 259) into a new token 314
# merging (256, 111) into a new token 315
# merging (114, 105) into a new token 316
# merging (276, 109) into a new token 317
# merging (119, 104) into a new token 318
# merging (311, 309) into a new token 319
# merging (104, 101) into a new token 320
# merging (97, 32) into a new token 321
# merging (97, 115) into a new token 322
# merging (112, 112) into a new token 323
# merging (117, 114) into a new token 324
# merging (284, 32) into a new token 325
# merging (258, 310) into a new token 326
# merging (117, 110) into a new token 327
# merging (114, 97) into a new token 328
# merging (119, 283) into a new token 329
# merging (111, 116) into a new token 330
# merging (269, 32) into a new token 331
# merging (100, 101) into a new token 332
# merging (277, 32) into a new token 333
# merging (118, 262) into a new token 334
# merging (260, 32) into a new token 335
# merging (103, 104) into a new token 336
# merging (98, 117) into a new token 337
# merging (119, 97) into a new token 338
# merging (107, 32) into a new token 339
# merging (108, 271) into a new token 340
# merging (119, 32) into a new token 341
# merging (97, 112) into a new token 342
# merging (108, 105) into a new token 343
# merging (97, 281) into a new token 344
# merging (97, 107) into a new token 345
# merging (268, 263) into a new token 346
# merging (268, 100) into a new token 347
# merging (97, 103) into a new token 348
# merging (105, 281) into a new token 349
# merging (102, 114) into a new token 350
# merging (277, 116) into a new token 351
# merging (114, 111) into a new token 352
# merging (288, 109) into a new token 353
# merging (112, 32) into a new token 354
# merging (105, 108) into a new token 355
# merging (118, 257) into a new token 356
# merging (284, 264) into a new token 357
# merging (104, 290) into a new token 358
# merging (44, 286) into a new token 359
# merging (105, 99) into a new token 360
# merging (111, 323) into a new token 361
# merging (111, 108) into a new token 362
# merging (101, 116) into a new token 363
# merging (307, 105) into a new token 364
# merging (105, 100) into a new token 365
# merging (267, 337) into a new token 366
# merging (350, 291) into a new token 367
# merging (117, 115) into a new token 368
# merging (108, 257) into a new token 369
# merging (118, 101) into a new token 370
# merging (110, 101) into a new token 371
# merging (319, 121) into a new token 372
# merging (104, 262) into a new token 373
# merging (258, 273) into a new token 374
# merging (97, 100) into a new token 375
# merging (99, 270) into a new token 376
# merging (105, 109) into a new token 377
# merging (278, 100) into a new token 378
# merging (275, 84) into a new token 379
# merging (329, 301) into a new token 380
# merging (78, 364) into a new token 381
# merging (90, 274) into a new token 382
# merging (108, 111) into a new token 383
# merging (282, 110) into a new token 384
# merging (260, 116) into a new token 385
# merging (119, 276) into a new token 386
# merging (292, 110) into a new token 387
# merging (83, 116) into a new token 388
# merging (319, 271) into a new token 389
# merging (261, 114) into a new token 390
# merging (115, 117) into a new token 391
# merging (105, 269) into a new token 392
# merging (99, 104) into a new token 393
# merging (268, 32) into a new token 394
# merging (288, 271) into a new token 395
# merging (299, 32) into a new token 396
# merging (296, 107) into a new token 397
# merging (98, 271) into a new token 398
# merging (306, 32) into a new token 399
# merging (102, 116) into a new token 400
# merging (261, 259) into a new token 401
# merging (101, 281) into a new token 402
# merging (99, 116) into a new token 403
# merging (102, 105) into a new token 404
# merging (97, 260) into a new token 405
# merging (97, 98) into a new token 406
# merging (282, 116) into a new token 407
# merging (99, 269) into a new token 408
# merging (58, 32) into a new token 409
# merging (268, 107) into a new token 410
# merging (111, 98) into a new token 411
# merging (282, 265) into a new token 412
# merging (338, 259) into a new token 413
# merging (328, 341) into a new token 414
# merging (305, 32) into a new token 415
# merging (99, 101) into a new token 416
# merging (388, 414) into a new token 417
# merging (417, 72) into a new token 418
# merging (101, 120) into a new token 419
# merging (288, 396) into a new token 420
# merging (270, 115) into a new token 421
# merging (366, 265) into a new token 422
# merging (99, 291) into a new token 423
# merging (117, 109) into a new token 424
# merging (108, 121) into a new token 425
# merging (275, 65) into a new token 426
# merging (329, 104) into a new token 427
# merging (101, 280) into a new token 428
# merging (115, 104) into a new token 429
# merging (101, 118) into a new token 430
# merging (115, 264) into a new token 431
# merging (105, 265) into a new token 432
# merging (44, 264) into a new token 433
# merging (269, 257) into a new token 434
# merging (106, 105) into a new token 435
# merging (284, 102) into a new token 436
# merging (260, 264) into a new token 437
# merging (418, 273) into a new token 438
# merging (85, 115) into a new token 439
# merging (315, 264) into a new token 440
# merging (115, 97) into a new token 441
# merging (439, 361) into a new token 442
# merging (102, 260) into a new token 443
# merging (105, 118) into a new token 444
# merging (117, 112) into a new token 445
# merging (115, 279) into a new token 446
# merging (99, 257) into a new token 447
# merging (261, 116) into a new token 448
# merging (101, 109) into a new token 449
# merging (299, 273) into a new token 450
# merging (275, 72) into a new token 451
# merging (115, 276) into a new token 452
# merging (98, 121) into a new token 453
# merging (336, 116) into a new token 454
# merging (103, 111) into a new token 455
# merging (289, 279) into a new token 456
# merging (119, 274) into a new token 457
# merging (111, 115) into a new token 458
# merging (101, 334) into a new token 459
# merging (114, 117) into a new token 460
# merging (317, 32) into a new token 461
# merging (318, 266) into a new token 462
# merging (112, 108) into a new token 463
# merging (108, 263) into a new token 464
# merging (269, 103) into a new token 465
# merging (83, 268) into a new token 466
# merging (466, 435) into a new token 467
# merging (115, 294) into a new token 468
# merging (105, 331) into a new token 469
# merging (272, 264) into a new token 470
# merging (349, 32) into a new token 471
# merging (99, 301) into a new token 472
# merging (367, 32) into a new token 473
# merging (97, 121) into a new token 474
# merging (273, 116) into a new token 475
# merging (111, 100) into a new token 476
# merging (353, 32) into a new token 477
# merging (115, 112) into a new token 478
# merging (98, 257) into a new token 479
# merging (293, 108) into a new token 480
# merging (268, 116) into a new token 481
# merging (113, 117) into a new token 482
# merging (111, 334) into a new token 483
# merging (115, 267) into a new token 484
# merging (39, 265) into a new token 485
# merging (114, 282) into a new token 486
# merging (277, 100) into a new token 487
# merging (67, 104) into a new token 488
# merging (117, 116) into a new token 489
# merging (99, 342) into a new token 490
# merging (382, 111) into a new token 491
# merging (262, 257) into a new token 492
# merging (121, 267) into a new token 493
# merging (111, 107) into a new token 494
# merging (109, 268) into a new token 495
# merging (390, 257) into a new token 496
# merging (324, 110) into a new token 497
# merging (99, 107) into a new token 498
# merging (344, 271) into a new token 499
# merging (103, 363) into a new token 500
# merging (110, 111) into a new token 501
# merging (100, 105) into a new token 502
# merging (82, 411) into a new token 503
# merging (99, 97) into a new token 504
# merging (101, 103) into a new token 505
# merging (100, 111) into a new token 506
# merging (379, 294) into a new token 507
# merging (117, 270) into a new token 508
# merging (99, 105) into a new token 509
# merging (102, 111) into a new token 510
# merging (438, 259) into a new token 511

# %%
for i in new_id:
    print(decode([i]))
# Out:
#  t
# e
#  th
# s
# in
#  a
# er
# d
#  the
# t
# o
# ,
# an
# on
# re
# y
# ing
# at
# or
# .
# hi
# en
#  an
#  to
# ar
# ll
# ou
# it
# of
# st
#  and
# ing
#  the
# es
# er
# om
# ow
# se
# he
# le
# ac
# ha
# be
# ir
# 's
# h
# es
#  a
# ed
# al
# for
# am
# is
# ff
# at
# Lu
# ed
# his
# is
#  to
# ri
# him
# wh
# Luff
# he
# a
# as
# pp
# ur
# of
#  that
# un
# ra
# wit
# ot
# on
# de
# en
# ver
# in
# gh
# bu
# wa
# k
# ly
# w
# ap
# li
# all
# ak
# and
# and
# ag
# ill
# fr
# ent
# ro
#  them
# p
# il
# ve
# of the
# her
# , and
# ic
# opp
# ol
# et
# ami
# id
# , bu
# from
# us
# le
# ve
# ne
# Luffy
# her
#  that
# ad
# cre
# im
#  and
# . T
# with
# Nami
# Zor
# lo
# oun
# int
# whi
# own
# St
# Luffy
#  ar
# su
# ion
# ch
# an
#  they
# ir
# ack
# by
# for
# ft
#  as
# ell
# ct
# fi
# ain
# ab
# out
# con
# :
# ank
# ob
# out
# was
# raw
# al
# ce
# Straw
# Straw H
# ex
#  their
# res
# , but
# com
# um
# ly
# . A
# with
# ear
# sh
# ev
# s the
# it
# , the
# one
# ji
# off
# in the
# Straw Hat
# Us
#  to the
# sa
# Usopp
# fin
# iv
# up
# s to
# ce
#  at
# em
# irat
# . H
# shi
# by
# ght
# go
# es to
# wor
# os
# ever
# ru
# him
# who
# pl
# ld
# ong
# San
# Sanji
# she
# ion
# ing the
# ill
# ch
# from
# ay
# att
# od
#  them
# sp
# be
# sel
# ant
# qu
# over
# s,
# 't
# rou
# end
# Ch
# ut
# cap
# Zoro
# ere
# y,
# ok
# man
#  are
# urn
# ck
# ally
# get
# no
# di
# Rob
# ca
# eg
# do
# . The
# ure
# ci
# fo
# Straw Hats

# %%
# Out:
# 'a'
